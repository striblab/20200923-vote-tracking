# %%
import pandas as pd

# %%
historical_totals = pd.read_excel('import/mn_ab_stats.xlsx')
historical_totals
# Out:
#         Numbers include all Absentee and Mail Ballots  \
# 0                                   Total Transmitted
# 1                            Replacements Transmitted
# 2                                       Undeliverable
# 3                                     Spoiled or Lost
# 4                                   Returned by Voter
# 5                                            Accepted
# 6                                    Rejected (Total)
# 7                     Rejected - Voter name not match
# 8                  Rejected - Voter address not match
# 9                       Rejected - No voter signature
# 10         Rejected - Voter number and sign not match
# 11                       Rejected - No signature date
# 12                        Rejected - NR Voter, No VRA
# 13  Rejected - NR voter, VRA returned separate fro...
# 14                Rejected - NR voter, VRA not signed
# 15            Rejected - NR voter, VRA deficient info
# ...
